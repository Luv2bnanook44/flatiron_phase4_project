# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import matplotlib.pyplot as plt
import scipy
import numpy as np
from PIL import Image
from scipy import ndimage
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.wrappers import scikit_learn
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import metrics
import tensorflow
from keras.layers import Dense, Dropout, Flatten
from keras import layers
from keras import models
from keras import optimizers
import matplotlib.pyplot as plt
# %matplotlib inline 
from PIL import Image, ImageOps

# %%
import os
base_dir='../data/chest_xray/'
train_pneumonia=os.listdir('../data_mirror/chest_xray/train/PNEUMONIA/')

train_normal=os.listdir('../data_mirror/chest_xray/train/NORMAL/')

val_dir_normal=os.listdir('../data_mirror/chest_xray/val/NORMAL/')

test_dir_normal=os.listdir('../data_mirror/chest_xray/test/NORMAL/')

val_dir_pneumonia=os.listdir('../data_mirror/chest_xray/val/PNEUMONIA/')

test_dir_pneumonia=os.listdir('../data_mirror/chest_xray/test/PNEUMONIA/')

# %%
#mirror_img('../data_mirror/chest_xray/train/PNEUMONIA/', '../data_mirror/chest_xray/train/PNEUMONIA/', train_pneumonia)
# Out:
# person1000_bacteria_2931.jpeg
# ['person1000_bacteria_2931', 'jpeg']
# person1000_virus_1681.jpeg
# ['person1000_virus_1681', 'jpeg']
# person1001_bacteria_2932.jpeg
# ['person1001_bacteria_2932', 'jpeg']
# person1002_bacteria_2933.jpeg
# ['person1002_bacteria_2933', 'jpeg']
# person1003_bacteria_2934.jpeg
# ['person1003_bacteria_2934', 'jpeg']
# person1003_virus_1685.jpeg
# ['person1003_virus_1685', 'jpeg']
# person1004_bacteria_2935.jpeg
# ['person1004_bacteria_2935', 'jpeg']
# person1004_virus_1686.jpeg
# ['person1004_virus_1686', 'jpeg']
# person1005_bacteria_2936.jpeg
# ['person1005_bacteria_2936', 'jpeg']
# person1005_virus_1688.jpeg
# ['person1005_virus_1688', 'jpeg']
# person1006_bacteria_2937.jpeg
# ['person1006_bacteria_2937', 'jpeg']
# person1007_bacteria_2938.jpeg
# ['person1007_bacteria_2938', 'jpeg']
# person1007_virus_1690.jpeg
# ['person1007_virus_1690', 'jpeg']
# person1008_bacteria_2939.jpeg
# ['person1008_bacteria_2939', 'jpeg']
# person1008_virus_1691.jpeg
# ...

# %%
#mirror_img('../data_mirror/chest_xray/train/NORMAL/', '../data_mirror/chest_xray/train/NORMAL/', train_normal)

# %%
print("Train set w/ pneumonia: ", len(train_pneumonia))
print("Train set normal: ", len(train_normal))
print("Validation set w/ pneumonia: ", len(val_dir_pneumonia))
print("Validation set normal: ", len(val_dir_normal))
print("Test set w/ pneumonia: ", len(test_dir_pneumonia))
print("Test set normal: ", len(test_dir_normal))
# Out:
# Train set w/ pneumonia:  4288
# Train set normal:  1398
# Validation set w/ pneumonia:  1740
# Validation set normal:  650
# Test set w/ pneumonia:  390
# Test set normal:  234

# %%
from keras.preprocessing.image import ImageDataGenerator, load_img
plt.suptitle('Normal Lungs')
for i in range(0,4):
    img = train_normal[i]
    img = load_img('../data/chest_xray/train/NORMAL/' + img)
    plt.imshow(img)
    plt.show()

# %%
def mirror_img(path_from, path_to, img_list):
    """Take a path to where images are located, a path to save transformed images 
    and the list of images to transform. Takes each image and returns the mirrored version of that image 
    with a new name marking its mirrored status"""
    for im in range(0, len(img_list)):
        full = img_list[im]
        #print(full)
        split = img_list[im]. split('.')
        #print(split)
        img = Image.open(path_from + full)
        img_mirror = ImageOps.mirror(img)
        img_mirror.save(path_to + split[0] + '_mirror' + '.jpeg', quality=95)

# %%
normal_img_arrays = []

for i in range(len(train_normal)):
    img = train_normal[i]
    img = load_img('../data/chest_xray/train/NORMAL/' + img)
    array = np.array(img)[:,:,0]
    normal_img_arrays.append(array)

# %%
normal_img_arrays[3].shape
# Out:
# (2363, 2288)

# %%
pneumonia_img_arrays = []

for i in range(len(train_pneumonia)):
    img = train_pneumonia[i]
    img = load_img('../data/chest_xray/train/PNEUMONIA/' + img)
    array = np.array(img)[:,:,0]
    pneumonia_img_arrays.append(array)

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory('../data_mirror/chest_xray/train/',
                                                 target_size=(224, 224),
                                                 shuffle=True,
                                                 batch_size=50,
                                                 class_mode='binary')

val_set = train_datagen.flow_from_directory('../data_mirror/chest_xray/val/',
                                            target_size=(224, 224),
                                            shuffle=True,
                                            batch_size=50,
                                            class_mode='binary')

test_set = test_datagen.flow_from_directory('../data_mirror/chest_xray/test/',
                                            target_size=(224, 224),
                                            shuffle=True,
                                            batch_size=10,
                                            class_mode='binary')
# Out:
# Found 5686 images belonging to 2 classes.
# Found 2390 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
model = Sequential()
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['categorical_accuracy'])
model.add(Flatten())
history = model.fit_generator(training_set,
                    epochs=10,
                    validation_data=val_set)

# %% [markdown]
# ## RMSprop(lr=1e-4) model

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer=optimizers.RMSprop(lr=1e-4),
              loss='binary_crossentropy',
              metrics=['acc'])

# %%
history = model.fit(training_set, 
                              steps_per_epoch=10, 
                              epochs=5, 
                              validation_data=val_set, 
                              validation_steps=5)
# Out:
# Epoch 1/5
# 10/10 [==============================] - 20s 2s/step - loss: 3.9131 - acc: 0.5800 - val_loss: 0.5675 - val_acc: 0.6800
# Epoch 2/5
# 10/10 [==============================] - 17s 2s/step - loss: 0.8884 - acc: 0.6920 - val_loss: 0.5666 - val_acc: 0.7440
# Epoch 3/5
# 10/10 [==============================] - 18s 2s/step - loss: 1.0161 - acc: 0.7260 - val_loss: 0.7118 - val_acc: 0.7160
# Epoch 4/5
# 10/10 [==============================] - 17s 2s/step - loss: 0.8938 - acc: 0.6820 - val_loss: 0.8206 - val_acc: 0.5360
# Epoch 5/5
# 10/10 [==============================] - 18s 2s/step - loss: 0.5047 - acc: 0.8060 - val_loss: 0.3242 - val_acc: 0.8480

# %% [markdown]
# ## adam Model

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tensorflow.keras.metrics.Recall()])


history = model.fit(training_set, 
                              steps_per_epoch=10, 
                              epochs=5, 
                              validation_data=val_set, 
                              validation_steps=5)
# Out:
# Epoch 1/5
# 10/10 [==============================] - 12s 1s/step - loss: 30.0154 - accuracy: 0.6300 - recall_1: 0.7816 - val_loss: 24.8565 - val_accuracy: 0.7640 - val_recall_1: 1.0000
# Epoch 2/5
# 10/10 [==============================] - 12s 1s/step - loss: 11.4590 - accuracy: 0.6340 - recall_1: 0.7302 - val_loss: 8.1977 - val_accuracy: 0.7160 - val_recall_1: 1.0000
# Epoch 3/5
# 10/10 [==============================] - 12s 1s/step - loss: 2.2454 - accuracy: 0.7920 - recall_1: 0.9039 - val_loss: 0.6873 - val_accuracy: 0.8320 - val_recall_1: 0.9326
# Epoch 4/5
# 10/10 [==============================] - 13s 1s/step - loss: 0.4930 - accuracy: 0.8860 - recall_1: 0.9153 - val_loss: 0.5892 - val_accuracy: 0.8400 - val_recall_1: 0.9349
# Epoch 5/5
# 10/10 [==============================] - 14s 1s/step - loss: 0.1982 - accuracy: 0.9480 - recall_1: 0.9593 - val_loss: 0.6211 - val_accuracy: 0.8360 - val_recall_1: 0.9471

# %%
loss_acc_rec_plotter(history)

# %%
def loss_acc_rec_plotter(history):
    """Takes the History object returned from model, pulls out relevant values and plot the training
    against validation for loss, accuracy and recall"""
    
    key_list = list(history.history.keys())
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    rec = history.history[key_list[2]]
    val_rec = history.history[key_list[5]]

    epochs = range(len(acc))

    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    plt.show()

    plt.plot(epochs, rec, 'bo', label='Training recall')
    plt.plot(epochs, val_rec, 'b', label='Validation recall')
    plt.title('Training and validation recall')
    plt.legend()
    plt.figure()

# %% [markdown]
# ## Adam model 2, 2nd layer

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tensorflow.keras.metrics.Recall()])


history = model.fit(training_set, 
                              steps_per_epoch=10, 
                              epochs=5, 
                              validation_data=val_set, 
                              validation_steps=5)
# Out:
# Epoch 1/5
# 10/10 [==============================] - 15s 2s/step - loss: 9.2146 - accuracy: 0.5300 - recall_2: 0.5844 - val_loss: 0.7447 - val_accuracy: 0.7040 - val_recall_2: 1.0000
# Epoch 2/5
# 10/10 [==============================] - 16s 2s/step - loss: 0.5887 - accuracy: 0.7380 - recall_2: 1.0000 - val_loss: 0.5529 - val_accuracy: 0.7560 - val_recall_2: 1.0000
# Epoch 3/5
# 10/10 [==============================] - 15s 2s/step - loss: 0.4796 - accuracy: 0.7780 - recall_2: 0.9690 - val_loss: 0.4646 - val_accuracy: 0.7440 - val_recall_2: 0.9719
# Epoch 4/5
# 10/10 [==============================] - 17s 2s/step - loss: 0.3122 - accuracy: 0.8920 - recall_2: 0.9519 - val_loss: 0.4399 - val_accuracy: 0.7680 - val_recall_2: 0.9249
# Epoch 5/5
# 10/10 [==============================] - 17s 2s/step - loss: 0.2696 - accuracy: 0.8780 - recall_2: 0.9517 - val_loss: 0.3352 - val_accuracy: 0.8360 - val_recall_2: 0.9508

# %%
loss_acc_rec_plotter(history)

# %% [markdown]
# ## adam model 3, model.fit rework, 12, 8, 8

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tensorflow.keras.metrics.Recall()])


history = model.fit(training_set, 
                              steps_per_epoch=12, 
                              epochs=8, 
                              validation_data=val_set, 
                              validation_steps=8)
# Out:
# Epoch 1/8
# 12/12 [==============================] - 22s 2s/step - loss: 5.0963 - accuracy: 0.6297 - recall_3: 0.7545 - val_loss: 0.5002 - val_accuracy: 0.7700 - val_recall_3: 0.9722
# Epoch 2/8
# 12/12 [==============================] - 21s 2s/step - loss: 0.3763 - accuracy: 0.8200 - recall_3: 0.9516 - val_loss: 0.3840 - val_accuracy: 0.8075 - val_recall_3: 0.9141
# Epoch 3/8
# 12/12 [==============================] - 21s 2s/step - loss: 0.2180 - accuracy: 0.9217 - recall_3: 0.9307 - val_loss: 0.3763 - val_accuracy: 0.8700 - val_recall_3: 0.9734
# Epoch 4/8
# 12/12 [==============================] - 21s 2s/step - loss: 0.1957 - accuracy: 0.9300 - recall_3: 0.9545 - val_loss: 0.2206 - val_accuracy: 0.8975 - val_recall_3: 0.9141
# Epoch 5/8
# 12/12 [==============================] - 21s 2s/step - loss: 0.1864 - accuracy: 0.9300 - recall_3: 0.9481 - val_loss: 0.2450 - val_accuracy: 0.9100 - val_recall_3: 0.9660
# Epoch 6/8
# ...

# %%
loss_acc_rec_plotter(history)

# %% [markdown]
# ## adam model 4, model.fit rework, 15, 10, 10

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tensorflow.keras.metrics.Recall()])


history = model.fit(training_set, 
                              steps_per_epoch=15, 
                              epochs=10, 
                              validation_data=val_set, 
                              validation_steps=10)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 25s 2s/step - loss: 3.5435 - accuracy: 0.6520 - recall_4: 0.7917 - val_loss: 0.5619 - val_accuracy: 0.7520 - val_recall_4: 1.0000
# Epoch 2/10
# 15/15 [==============================] - 25s 2s/step - loss: 0.4105 - accuracy: 0.8107 - recall_4: 0.9585 - val_loss: 0.5131 - val_accuracy: 0.7540 - val_recall_4: 0.9667
# Epoch 3/10
# 15/15 [==============================] - 26s 2s/step - loss: 0.2738 - accuracy: 0.8940 - recall_4: 0.9375 - val_loss: 0.2811 - val_accuracy: 0.8840 - val_recall_4: 0.9465
# Epoch 4/10
# 15/15 [==============================] - 27s 2s/step - loss: 0.1912 - accuracy: 0.9307 - recall_4: 0.9493 - val_loss: 0.2262 - val_accuracy: 0.9100 - val_recall_4: 0.9833
# Epoch 5/10
# 15/15 [==============================] - 27s 2s/step - loss: 0.1244 - accuracy: 0.9573 - recall_4: 0.9657 - val_loss: 0.1731 - val_accuracy: 0.9300 - val_recall_4: 0.9533
# Epoch 6/10
# ...

# %%
loss_acc_rec_plotter(history)

# %% [markdown]
# ## SGD Model

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy', tensorflow.keras.metrics.Recall()])


history = model.fit(training_set, 
                              steps_per_epoch=10, 
                              epochs=5, 
                              validation_data=test_set, 
                              validation_steps=5)
# Out:
# Epoch 1/5
# 10/10 [==============================] - 9s 906ms/step - loss: 0.7754 - accuracy: 0.7260 - recall_5: 0.8962 - val_loss: 0.7299 - val_accuracy: 0.6400 - val_recall_5: 1.0000
# Epoch 2/5
# 10/10 [==============================] - 10s 1s/step - loss: 0.5374 - accuracy: 0.7480 - recall_5: 1.0000 - val_loss: 0.7179 - val_accuracy: 0.5800 - val_recall_5: 1.0000
# Epoch 3/5
# 10/10 [==============================] - 10s 978ms/step - loss: 0.5072 - accuracy: 0.7340 - recall_5: 0.9143 - val_loss: 0.6103 - val_accuracy: 0.6600 - val_recall_5: 1.0000
# Epoch 4/5
# 10/10 [==============================] - 10s 992ms/step - loss: 0.4915 - accuracy: 0.7880 - recall_5: 0.9974 - val_loss: 0.6289 - val_accuracy: 0.6800 - val_recall_5: 1.0000
# Epoch 5/5
# 10/10 [==============================] - 11s 1s/step - loss: 0.4369 - accuracy: 0.8160 - recall_5: 0.9920 - val_loss: 0.6627 - val_accuracy: 0.5600 - val_recall_5: 1.0000

# %%
loss_acc_rec_plotter(history)

# %% [markdown]
# ## SGD model 2 more layers

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy',tensorflow.keras.metrics.Recall()])


history = model.fit(training_set, 
                              steps_per_epoch=10, 
                              epochs=5, 
                              validation_data=test_set, 
                              validation_steps=5)
# Out:
# Epoch 1/5
# 10/10 [==============================] - 14s 1s/step - loss: 0.5515 - accuracy: 0.7860 - recall_11: 1.0000 - val_loss: 0.7760 - val_accuracy: 0.6600 - val_recall_11: 1.0000
# Epoch 2/5
# 10/10 [==============================] - 13s 1s/step - loss: 0.5698 - accuracy: 0.6755 - recall_11: 0.8944 - val_loss: 0.6533 - val_accuracy: 0.6000 - val_recall_11: 1.0000
# Epoch 3/5
# 10/10 [==============================] - 13s 1s/step - loss: 0.4719 - accuracy: 0.7880 - recall_11: 1.0000 - val_loss: 0.6864 - val_accuracy: 0.6000 - val_recall_11: 1.0000
# Epoch 4/5
# 10/10 [==============================] - 14s 1s/step - loss: 0.4977 - accuracy: 0.7840 - recall_11: 0.9605 - val_loss: 0.6175 - val_accuracy: 0.6600 - val_recall_11: 1.0000
# Epoch 5/5
# 10/10 [==============================] - 14s 1s/step - loss: 0.4332 - accuracy: 0.8100 - recall_11: 0.9738 - val_loss: 1.0418 - val_accuracy: 0.6000 - val_recall_11: 1.0000

# %%
loss_acc_rec_plotter(history)
